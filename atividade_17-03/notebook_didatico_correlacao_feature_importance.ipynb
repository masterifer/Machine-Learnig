# %% [markdown]
# # Notebook didático — Correlação e Feature Importance
#
# Este notebook mostra como a correlação entre variáveis pode influenciar a interpretação de modelos.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
np.random.seed(42)
n = 1000
x1 = np.random.normal(size=n)
x2 = x1 + np.random.normal(scale=0.1, size=n)  # altamente correlacionada
x3 = np.random.normal(size=n)
y = (x1 + x3 > 0).astype(int)
df = pd.DataFrame({'x1':x1,'x2':x2,'x3':x3,'target':y})
df.head()
# Out:
#          x1        x2        x3  target
# 0  0.496714  0.636650 -0.675178       0
# 1 -0.138264 -0.045801 -0.144519       0
# 2  0.647689  0.653652 -0.792420       0
# 3  1.523030  1.458336 -0.307962       1
# 4 -0.234153 -0.164331 -1.893615       0

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlação entre variáveis')
plt.show()

# %% [markdown]
# Observe que **x1** e **x2** são altamente correlacionadas. Isso significa que parte da informação é redundante.

# %%
X = df[['x1','x2','x3']]
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = DecisionTreeClassifier(max_depth=4, random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
imp = model.feature_importances_
plt.bar(['x1','x2','x3'], imp)
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# Se duas variáveis carregam informação parecida, o modelo pode dividir a importância entre elas ou favorecer apenas uma. Por isso feature importance precisa ser interpretada com cuidado.
